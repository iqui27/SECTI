# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="LEieaDr8RQksx8CxwJU0WggnRNj7Xtj2")

# Lê o arquivo csv
df = pd.read_excel('/Users/henrique/Documents/SECTI/caminho_da_planilha_atualizada.xlsx')

df cccccbcvdkvnvgbncndrgrdlnrgjlebvblhnrvtfguug
# Out:
#      Unnamed: 0                                           endereco  \
# 0             1                   Administração Regional da Fercal
# 1             2                   Administração Regional do Itapoã
# 2             3                  Administração Regional do Paranoá
# 3             4     Apoio de Atendimento ao CRAS Engenho das Lajes
# 4             5              Avenida Central da Cidade  Estrutural
# ..          ...                                                ...
# 109         110  Vale da Benção - Núcleo Rural Kanegai (Ch. 12 ...
# 110         111                                        Vila do Boa
# 111         112                                      Vila Rabelo I
# 112         113                                         Vila Roriz
# 113         114                              Zoológico de Brasília
#
#                     Unnamed: 2      Unnamed: 3        lon        lat
# 0               SEPLAD (SUTIC)          FERCAL -47.872429 -15.600184
# 1    I-Digitais - Acesso Livre          ITAPOÃ -47.760901 -15.744788
# 2    I-Digitais - Acesso Livre         PARANOÁ -47.780183 -15.778817
# 3               SEPLAD (SUTIC)            GAMA -39.452500  -6.095280
# 4        Plus Midia (Uaifácil)      ESTRUTURAL        NaN        NaN
# ..                         ...             ...        ...        ...
# 109             SEPLAD (SUTIC)  RIACHO FUNDO I        NaN        NaN
# 110             SEPLAD (SUTIC)   SÃO SEBASTIÃO -47.790727 -15.879466
# 111             SEPLAD (SUTIC)   SOBRADINHO II -35.001779  -8.110309
# 112             SEPLAD (SUTIC)            GAMA -47.950673 -16.243067
# 113             SEPLAD (SUTIC)  CANDANGOLÂNDIA -47.940026 -15.846932
#
# [114 rows x 6 columns]

# %%
# Cria um mapa
mapa = folium.Map(location=[-23.5489, -46.6388], zoom_start=12)
mapa.save('mapa.html')

# Cria um marcador para cada linha do arquivo csv
for index, coll in df.iterrows():
    folium.Marker([row['lat'], row['lon']], popup=row['nome']).add_to(mapa)
    
    endereco = coll['endereco']
    lat = coll['lat']
    lon = coll['lon']
    popup = endereco
    
    marker = folium.Marker(location=[lat, lon], popup=popup)
    marker.add_to(mapa)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nome'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 7
#       5 # Cria um marcador para cada linha do arquivo csv
#       6 for index, coll in df.iterrows():
# ----> 7     folium.Marker([coll['lat'], coll['lon']], popup=coll['nome']).add_to(mapa)
#       9     endereco = coll['endereco']
#      10     lat = coll['lat']
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'nome'
